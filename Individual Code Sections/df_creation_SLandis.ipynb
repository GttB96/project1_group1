# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plot 

# File to Load

spotify_data_load = Path("Resources/spotify_songs .csv")

# Read Data File and store into Pandas DataFrames
spotify_data= pd.read_csv(spotify_data_load)
spotify_data_drop = spotify_data.drop(columns =['track_album_id', 'playlist_id', 'track_album_name',
                                        'danceability', 'energy', 'mode', 'speechiness', 'acousticness',
                                        'instrumentalness', 'liveness', 'valence'])
# Show DateFrame
spotify_data_drop.head(20)
# Out:
#                   track_id                                         track_name  \
# 0   0CmIALzGn4vHIHJG4n3Q4z                           At Last - Single Version
# 1   27K3ZDS5B4fwjhwyihrdzC              (What A) Wonderful World - Remastered
# 2   7jER4hFurkqwYmeat3qsh5                                       Jingle Bells
# 3   1nd9moIZkGvWoHtReFqkRY                           At Last - Single Version
# 4   4fQMGlCawbTkH9yPPZ49kP                                       Green Onions
# 5   4fQMGlCawbTkH9yPPZ49kP                                       Green Onions
# 6   46pF1zFimM582ss1PrMy68                  Christmas (Baby Please Come Home)
# 7   3svlCHYt8YCtAYXjKhrpUs                                  Winter Wonderland
# 8   5PHGTeEdFxTEb4hepxug86  Turn! Turn! Turn! (To Everything There Is a Se...
# 9   0O8Gf1dTGNbEaSYSGk1pcS                              Que Bueno Baila Usted
# 10  76ICmoJ4PcoMWoooaTxnQs                                Land of 1000 Dances
# 11  51FpzuGkRYXFgsE2zXt9av                           When a Man Loves a Woman
# 12  7vqubB6rY1NpGVGpHYobbQ                                        Without You
# 13  7CAhxeaTYXn1qWNRkZl9ad       Everybody's Talkin' - From "Midnight Cowboy"
# 14  0AyAhgf2sihNnGt1ymLhg2                                           My Death
# 15  4vpeKl0vMGdAXpZiQB2Dtd                                       White Rabbit
# 16  5qyq1H5OPMlfuvZQ1wQNo7       (Your Love Keeps Lifting Me) Higher & Higher
# 17  0bfvHnWWOeU1U5XeKyVLbW                         Can't Take My Eyes off You
# 18  1Qc7zCw6k2KTvSEl4IKSdP                                         The Pusher
# 19  7r3Hwig1mvtlVq0ZbJ09Wb                                          Slip Away
#
#               track_artist  track_popularity  track_album_release_date  \
# 0               Etta James                25                      1960
# 1                Sam Cooke                13                      1960
# 2          Ella Fitzgerald                11                      1960
# 3               Etta James                15                      1960
# 4   Booker T. & the M.G.'s                64                      1962
# 5   Booker T. & the M.G.'s                64                      1962
# 6             Darlene Love                73                      1963
# 7          Aretha Franklin                45                      1964
# 8                The Byrds                42                      1965
# 9                Beny Moré                40                      1965
# 10          Wilson Pickett                61                      1966
# 11            Percy Sledge                66                      1966
# 12           Harry Nilsson                10                      1967
# 13           Harry Nilsson                10                      1967
# 14            Scott Walker                24                      1967
# 15      Jefferson Airplane                69                      1967
# 16           Jackie Wilson                67                      1967
# 17           Frankie Valli                65                      1967
# 18             Steppenwolf                54                      1968
# 19         Clarence Carter                53                      1968
#
#                                         playlist_name playlist_genre  \
# 0   The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...            r&b
# 1   The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...            r&b
# 2                                      Christmas Soul            r&b
# 3                                      Sexy Soul 2020            r&b
# 4                           Supernatural Classic Rock           rock
# 5   The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...            r&b
# 6                                      Christmas Soul            r&b
# 7                                      Christmas Soul            r&b
# 8                                        Classic Rock           rock
# 9                                    Cuban vibes only            r&b
# 10  The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...            r&b
# 11                                     Sexy Soul 2020            r&b
# 12                70s Pop & Rock Hits and Deep Tracks           rock
# 13                70s Pop & Rock Hits and Deep Tracks           rock
# 14                                     Permanent Wave           rock
# 15                                     Permanent Wave           rock
# 16  The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...            r&b
# 17  The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...            r&b
# 18                                        Badass Rock            rap
# 19                              Southern Soul BBQ Mix            rap
#
#      playlist_subgenre  key  loudness    tempo  duration_ms
# 0   urban contemporary    5    -9.981  174.794       182400
# 1   urban contemporary   11    -9.889  128.091       125507
# 2             neo soul    7    -6.295  119.117       142547
# 3             neo soul    5    -9.881  174.610       179893
# 4         classic rock   10    -8.741  136.837       176333
# 5   urban contemporary   10    -8.741  136.837       176333
# 6             neo soul    3    -7.146  126.322       166453
# 7             neo soul    7    -8.026  106.274       132107
# 8         classic rock    2    -8.170  124.594       229533
# 9   urban contemporary    5    -9.712  172.230       196933
# 10  urban contemporary    2   -11.624   86.903       146973
# 11            neo soul    1   -20.410   97.398       173867
# 12          album rock    4   -13.657   65.311       202027
# 13          album rock    4   -10.964  124.411       164907
# 14      permanent wave    4   -16.437   82.417       297480
# 15      permanent wave    2   -12.503  106.798       150640
# 16  urban contemporary    2    -7.190   95.792       179120
# 17  urban contemporary    4    -7.053  123.711       203680
# 18    southern hip hop    0   -13.807   81.754       350467
# 19    southern hip hop    1    -9.100  113.491       153298

# %%
#Check 
spotify_data_drop.dtypes
# Out:
# track_id                     object
# track_name                   object
# track_artist                 object
# track_popularity              int64
# track_album_release_date      int64
# playlist_name                object
# playlist_genre               object
# playlist_subgenre            object
# key                           int64
# loudness                    float64
# tempo                       float64
# duration_ms                   int64
# dtype: object

# %%
#Make it pretty 
spotify_df = spotify_data_drop.rename(columns={"track_name": "Track Name", "track_artist": "Artist", "track_popularity": "Popularity",
                          "track_album_release_date": "Release Date", "playlist_name": "Playlist Name",
                          "playlist_genre": "Genre", "playlist_subgenre": "Subgenre", "key": "Key",
                          "loudness": "Loudness","tempo": "Tempo", "duration_ms": "Duration (ms)"})
spotify_df = spotify_df.set_index(["Track Name"])
spotify_df['Tempo'] =spotify_df['Tempo'].map('{:.3f}'.format)
spotify_df['Loudness'] =spotify_df['Loudness'].map('{:.3f}'.format)

#Print data frame
spotify_df
# Out:
#                                                      track_id  \
# Track Name
# At Last - Single Version               0CmIALzGn4vHIHJG4n3Q4z
# (What A) Wonderful World - Remastered  27K3ZDS5B4fwjhwyihrdzC
# Jingle Bells                           7jER4hFurkqwYmeat3qsh5
# At Last - Single Version               1nd9moIZkGvWoHtReFqkRY
# Green Onions                           4fQMGlCawbTkH9yPPZ49kP
# ...                                                       ...
# Top Of The Bill - Live                 3JXOMZdeJ7uMR7UfC3BN5T
# Wavelength - Remastered                6KrMDGTp9CtkMLKyftDUTD
# Der Mussolini - 1998 - Remaster        4bnNwCbIo9vxlIpu88KV0K
# Bedsitter                              6ZMda6mscE8eRkuwlw8yFB
# Tainted Love                           4GDmAT5ZZyHdBo32UYDIvM
#
#                                                        Artist  Popularity  \
# Track Name
# At Last - Single Version                           Etta James          25
# (What A) Wonderful World - Remastered               Sam Cooke          13
# Jingle Bells                                  Ella Fitzgerald          11
# At Last - Single Version                           Etta James          15
# Green Onions                           Booker T. & the M.G.'s          64
# ...                                                       ...         ...
# Top Of The Bill - Live                              Scorpions           2
# Wavelength - Remastered                          Van Morrison          44
# Der Mussolini - 1998 - Remaster                           DAF           2
# Bedsitter                                           Soft Cell          18
# Tainted Love                                        Soft Cell          53
#
#                                        Release Date  \
# Track Name
# At Last - Single Version                       1960
# (What A) Wonderful World - Remastered          1960
# Jingle Bells                                   1960
# At Last - Single Version                       1960
# Green Onions                                   1962
# ...                                             ...
# Top Of The Bill - Live                         1978
# Wavelength - Remastered                        1978
# Der Mussolini - 1998 - Remaster                1981
# Bedsitter                                      1981
# Tainted Love                                   1981
#
#                                                                            Playlist Name  \
# Track Name
# At Last - Single Version               The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...
# (What A) Wonderful World - Remastered  The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...
# Jingle Bells                                                              Christmas Soul
# At Last - Single Version                                                  Sexy Soul 2020
# Green Onions                                                   Supernatural Classic Rock
# ...                                                                                  ...
# Top Of The Bill - Live                                                 This Is Scorpions
# Wavelength - Remastered                                          Classic Rock Retrogamer
# Der Mussolini - 1998 - Remaster        Gothic / Industrial / Mittelalter / EBM / Futu...
# Bedsitter                              Maxi Pop  GOLD (New Wave, Electropop, Synth Po...
# Tainted Love                                                          Classic Rock Radio
#
#                                       Genre            Subgenre  Key Loudness  \
# Track Name
# At Last - Single Version                r&b  urban contemporary    5   -9.981
# (What A) Wonderful World - Remastered   r&b  urban contemporary   11   -9.889
# Jingle Bells                            r&b            neo soul    7   -6.295
# At Last - Single Version                r&b            neo soul    5   -9.881
# Green Onions                           rock        classic rock   10   -8.741
# ...                                     ...                 ...  ...      ...
# Top Of The Bill - Live                 rock           hard rock    3   -6.118
# Wavelength - Remastered                rock        classic rock    0   -6.999
# Der Mussolini - 1998 - Remaster         pop          electropop    6   -9.404
# Bedsitter                               pop          electropop    7   -9.121
# Tainted Love                           rock        classic rock    0   -8.057
#
#                                          Tempo  Duration (ms)
# Track Name
# At Last - Single Version               174.794         182400
# (What A) Wonderful World - Remastered  128.091         125507
# Jingle Bells                           119.117         142547
# At Last - Single Version               174.610         179893
# Green Onions                           136.837         176333
# ...                                        ...            ...
# Top Of The Bill - Live                 142.665         407333
# Wavelength - Remastered                142.829         346987
# Der Mussolini - 1998 - Remaster        156.308         235107
# Bedsitter                              145.271         215333
# Tainted Love                           144.543         153880
#
# [32833 rows x 11 columns]

# %%
#Define the number assignments of the key in letter form. 
#Create new column for the letter key
def key_assign(key):
    if key == 0:
        return("C")
    elif key == 1:
        return('C#')
    elif key == 2:
        return('D')
    elif key == 3:
        return('D#')
    elif key == 4:
        return('E')
    elif key == 5:
        return("F")
    elif key == 6:
        return('F#')
    elif key == 7:
        return('G')
    elif key == 8:
        return('G#')
    elif key == 9:
        return('A')
    elif key == 10:
        return('A#')
    elif key == 11:
        return('B')
    else:
        return('No Key Detected')

spotify_df["Key Assignment"] = spotify_df['Key'].apply(key_assign)

#Display new data frame
spotify_df
# Out:
#                                                      track_id  \
# Track Name
# At Last - Single Version               0CmIALzGn4vHIHJG4n3Q4z
# (What A) Wonderful World - Remastered  27K3ZDS5B4fwjhwyihrdzC
# Jingle Bells                           7jER4hFurkqwYmeat3qsh5
# At Last - Single Version               1nd9moIZkGvWoHtReFqkRY
# Green Onions                           4fQMGlCawbTkH9yPPZ49kP
# ...                                                       ...
# Top Of The Bill - Live                 3JXOMZdeJ7uMR7UfC3BN5T
# Wavelength - Remastered                6KrMDGTp9CtkMLKyftDUTD
# Der Mussolini - 1998 - Remaster        4bnNwCbIo9vxlIpu88KV0K
# Bedsitter                              6ZMda6mscE8eRkuwlw8yFB
# Tainted Love                           4GDmAT5ZZyHdBo32UYDIvM
#
#                                                        Artist  Popularity  \
# Track Name
# At Last - Single Version                           Etta James          25
# (What A) Wonderful World - Remastered               Sam Cooke          13
# Jingle Bells                                  Ella Fitzgerald          11
# At Last - Single Version                           Etta James          15
# Green Onions                           Booker T. & the M.G.'s          64
# ...                                                       ...         ...
# Top Of The Bill - Live                              Scorpions           2
# Wavelength - Remastered                          Van Morrison          44
# Der Mussolini - 1998 - Remaster                           DAF           2
# Bedsitter                                           Soft Cell          18
# Tainted Love                                        Soft Cell          53
#
#                                        Release Date  \
# Track Name
# At Last - Single Version                       1960
# (What A) Wonderful World - Remastered          1960
# Jingle Bells                                   1960
# At Last - Single Version                       1960
# Green Onions                                   1962
# ...                                             ...
# Top Of The Bill - Live                         1978
# Wavelength - Remastered                        1978
# Der Mussolini - 1998 - Remaster                1981
# Bedsitter                                      1981
# Tainted Love                                   1981
#
#                                                                            Playlist Name  \
# Track Name
# At Last - Single Version               The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...
# (What A) Wonderful World - Remastered  The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...
# Jingle Bells                                                              Christmas Soul
# At Last - Single Version                                                  Sexy Soul 2020
# Green Onions                                                   Supernatural Classic Rock
# ...                                                                                  ...
# Top Of The Bill - Live                                                 This Is Scorpions
# Wavelength - Remastered                                          Classic Rock Retrogamer
# Der Mussolini - 1998 - Remaster        Gothic / Industrial / Mittelalter / EBM / Futu...
# Bedsitter                              Maxi Pop  GOLD (New Wave, Electropop, Synth Po...
# Tainted Love                                                          Classic Rock Radio
#
#                                       Genre            Subgenre  Key Loudness  \
# Track Name
# At Last - Single Version                r&b  urban contemporary    5   -9.981
# (What A) Wonderful World - Remastered   r&b  urban contemporary   11   -9.889
# Jingle Bells                            r&b            neo soul    7   -6.295
# At Last - Single Version                r&b            neo soul    5   -9.881
# Green Onions                           rock        classic rock   10   -8.741
# ...                                     ...                 ...  ...      ...
# Top Of The Bill - Live                 rock           hard rock    3   -6.118
# Wavelength - Remastered                rock        classic rock    0   -6.999
# Der Mussolini - 1998 - Remaster         pop          electropop    6   -9.404
# Bedsitter                               pop          electropop    7   -9.121
# Tainted Love                           rock        classic rock    0   -8.057
#
#                                          Tempo  Duration (ms) Key Assignment
# Track Name
# At Last - Single Version               174.794         182400              F
# (What A) Wonderful World - Remastered  128.091         125507              B
# Jingle Bells                           119.117         142547              G
# At Last - Single Version               174.610         179893              F
# Green Onions                           136.837         176333             A#
# ...                                        ...            ...            ...
# Top Of The Bill - Live                 142.665         407333             D#
# Wavelength - Remastered                142.829         346987              C
# Der Mussolini - 1998 - Remaster        156.308         235107             F#
# Bedsitter                              145.271         215333              G
# Tainted Love                           144.543         153880              C
#
# [32833 rows x 12 columns]

# %%
#Categorize and Establish Bins for Popularity
size_bins = (0, 30, 60, 90, 100)
labels = ['Least Popular (<30)', 'Low to Mid Popular (30-59)',
          'Mid to High Popular (60-89)','Most Popular (90-100)'] 

spotify_df["Popularity Sectors"] = pd.cut(spotify_df["Popularity"],size_bins, labels=labels)

#Organize Columns
spotify_df =spotify_df.reindex(columns=['Artist', 'Popularity', 'Popularity Sectors', 'Release Date',
                                       'Playlist Name', 'Genre', 'Subgenre', 'Key', 'Key Assignment',
                                       'Loudness', 'Tempo', 'Duration (ms)'])
#Print data frame
spotify_df
# Out:
#                                                        Artist  Popularity  \
# Track Name
# At Last - Single Version                           Etta James          25
# (What A) Wonderful World - Remastered               Sam Cooke          13
# Jingle Bells                                  Ella Fitzgerald          11
# At Last - Single Version                           Etta James          15
# Green Onions                           Booker T. & the M.G.'s          64
# ...                                                       ...         ...
# Top Of The Bill - Live                              Scorpions           2
# Wavelength - Remastered                          Van Morrison          44
# Der Mussolini - 1998 - Remaster                           DAF           2
# Bedsitter                                           Soft Cell          18
# Tainted Love                                        Soft Cell          53
#
#                                                 Popularity Sectors  \
# Track Name
# At Last - Single Version                       Least Popular (<30)
# (What A) Wonderful World - Remastered          Least Popular (<30)
# Jingle Bells                                   Least Popular (<30)
# At Last - Single Version                       Least Popular (<30)
# Green Onions                           Mid to High Popular (60-89)
# ...                                                            ...
# Top Of The Bill - Live                         Least Popular (<30)
# Wavelength - Remastered                 Low to Mid Popular (30-59)
# Der Mussolini - 1998 - Remaster                Least Popular (<30)
# Bedsitter                                      Least Popular (<30)
# Tainted Love                            Low to Mid Popular (30-59)
#
#                                        Release Date  \
# Track Name
# At Last - Single Version                       1960
# (What A) Wonderful World - Remastered          1960
# Jingle Bells                                   1960
# At Last - Single Version                       1960
# Green Onions                                   1962
# ...                                             ...
# Top Of The Bill - Live                         1978
# Wavelength - Remastered                        1978
# Der Mussolini - 1998 - Remaster                1981
# Bedsitter                                      1981
# Tainted Love                                   1981
#
#                                                                            Playlist Name  \
# Track Name
# At Last - Single Version               The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...
# (What A) Wonderful World - Remastered  The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...
# Jingle Bells                                                              Christmas Soul
# At Last - Single Version                                                  Sexy Soul 2020
# Green Onions                                                   Supernatural Classic Rock
# ...                                                                                  ...
# Top Of The Bill - Live                                                 This Is Scorpions
# Wavelength - Remastered                                          Classic Rock Retrogamer
# Der Mussolini - 1998 - Remaster        Gothic / Industrial / Mittelalter / EBM / Futu...
# Bedsitter                              Maxi Pop  GOLD (New Wave, Electropop, Synth Po...
# Tainted Love                                                          Classic Rock Radio
#
#                                       Genre            Subgenre  Key  \
# Track Name
# At Last - Single Version                r&b  urban contemporary    5
# (What A) Wonderful World - Remastered   r&b  urban contemporary   11
# Jingle Bells                            r&b            neo soul    7
# At Last - Single Version                r&b            neo soul    5
# Green Onions                           rock        classic rock   10
# ...                                     ...                 ...  ...
# Top Of The Bill - Live                 rock           hard rock    3
# Wavelength - Remastered                rock        classic rock    0
# Der Mussolini - 1998 - Remaster         pop          electropop    6
# Bedsitter                               pop          electropop    7
# Tainted Love                           rock        classic rock    0
#
#                                       Key Assignment Loudness    Tempo  \
# Track Name
# At Last - Single Version                           F   -9.981  174.794
# (What A) Wonderful World - Remastered              B   -9.889  128.091
# Jingle Bells                                       G   -6.295  119.117
# At Last - Single Version                           F   -9.881  174.610
# Green Onions                                      A#   -8.741  136.837
# ...                                              ...      ...      ...
# Top Of The Bill - Live                            D#   -6.118  142.665
# Wavelength - Remastered                            C   -6.999  142.829
# Der Mussolini - 1998 - Remaster                   F#   -9.404  156.308
# Bedsitter                                          G   -9.121  145.271
# Tainted Love                                       C   -8.057  144.543
#
#                                        Duration (ms)
# Track Name
# At Last - Single Version                      182400
# (What A) Wonderful World - Remastered         125507
# Jingle Bells                                  142547
# At Last - Single Version                      179893
# Green Onions                                  176333
# ...                                              ...
# Top Of The Bill - Live                        407333
# Wavelength - Remastered                       346987
# Der Mussolini - 1998 - Remaster               235107
# Bedsitter                                     215333
# Tainted Love                                  153880
#
# [32833 rows x 12 columns]

# %%
#Key Data
#Drop un-needed columns
key_df = spotify_df.drop(columns={'Release Date', 'Playlist Name', 'Genre',
                         'Subgenre', 'Loudness', 'Tempo', 'Duration (ms)'})
#Print data frame
key_df
# Out:
#                                                        Artist  Popularity  \
# Track Name
# At Last - Single Version                           Etta James          25
# (What A) Wonderful World - Remastered               Sam Cooke          13
# Jingle Bells                                  Ella Fitzgerald          11
# At Last - Single Version                           Etta James          15
# Green Onions                           Booker T. & the M.G.'s          64
# ...                                                       ...         ...
# Top Of The Bill - Live                              Scorpions           2
# Wavelength - Remastered                          Van Morrison          44
# Der Mussolini - 1998 - Remaster                           DAF           2
# Bedsitter                                           Soft Cell          18
# Tainted Love                                        Soft Cell          53
#
#                                                 Popularity Sectors  Key  \
# Track Name
# At Last - Single Version                       Least Popular (<30)    5
# (What A) Wonderful World - Remastered          Least Popular (<30)   11
# Jingle Bells                                   Least Popular (<30)    7
# At Last - Single Version                       Least Popular (<30)    5
# Green Onions                           Mid to High Popular (60-89)   10
# ...                                                            ...  ...
# Top Of The Bill - Live                         Least Popular (<30)    3
# Wavelength - Remastered                 Low to Mid Popular (30-59)    0
# Der Mussolini - 1998 - Remaster                Least Popular (<30)    6
# Bedsitter                                      Least Popular (<30)    7
# Tainted Love                            Low to Mid Popular (30-59)    0
#
#                                       Key Assignment
# Track Name
# At Last - Single Version                           F
# (What A) Wonderful World - Remastered              B
# Jingle Bells                                       G
# At Last - Single Version                           F
# Green Onions                                      A#
# ...                                              ...
# Top Of The Bill - Live                            D#
# Wavelength - Remastered                            C
# Der Mussolini - 1998 - Remaster                   F#
# Bedsitter                                          G
# Tainted Love                                       C
#
# [32833 rows x 5 columns]

# %%
#Group and Count each letter in Key Assignment
key_group = key_df.groupby(['Key Assignment']).size()
key_group
# Out:
# Key Assignment
# A     3027
# A#    2273
# B     2996
# C     3454
# C#    4010
# D     2827
# D#     913
# E     2201
# F     2680
# F#    2670
# G     3352
# G#    2430
# dtype: int64

# %%
key_group_2 = key_df.groupby(['Popularity Sectors'])['Key Assignment'].value_counts()
key_group_2 =pd.DataFrame(key_group_2)
key_group_2 = key_group_2.sort_values('Key Assignment')

key_group_2
# Out:
#                                             count
# Popularity Sectors          Key Assignment
# Mid to High Popular (60-89) A                 811
# Least Popular (<30)         A                 620
# Most Popular (90-100)       A                  19
# Low to Mid Popular (30-59)  A                1293
#                             A#                973
# Mid to High Popular (60-89) A#                580
# Most Popular (90-100)       A#                 38
# Least Popular (<30)         A#                476
# Mid to High Popular (60-89) B                 802
# Low to Mid Popular (30-59)  B                1259
# Least Popular (<30)         B                 644
# Most Popular (90-100)       B                  22
# Least Popular (<30)         C                 784
# Mid to High Popular (60-89) C                 969
# Low to Mid Popular (30-59)  C                1452
# Most Popular (90-100)       C                  10
# Least Popular (<30)         C#                886
# Low to Mid Popular (30-59)  C#               1696
# Most Popular (90-100)       C#                 32
# Mid to High Popular (60-89) C#               1087
#                             D                 711
# Most Popular (90-100)       D                  28
# Least Popular (<30)         D                 663
# Low to Mid Popular (30-59)  D                1183
# Mid to High Popular (60-89) D#                224
# Low to Mid Popular (30-59)  D#                404
# Most Popular (90-100)       D#                  0
# Least Popular (<30)         D#                216
#                             E                 493
# Most Popular (90-100)       E                   7
# Mid to High Popular (60-89) E                 575
# Low to Mid Popular (30-59)  E                 924
#                             F                1133
# Mid to High Popular (60-89) F                 724
# Least Popular (<30)         F                 583
# Most Popular (90-100)       F                   8
# Mid to High Popular (60-89) F#                704
# Low to Mid Popular (30-59)  F#               1113
# Most Popular (90-100)       F#                 33
# Least Popular (<30)         F#                609
# Low to Mid Popular (30-59)  G                1383
# Mid to High Popular (60-89) G                 792
# Least Popular (<30)         G                 858
# Most Popular (90-100)       G                  44
# Least Popular (<30)         G#                473
# Low to Mid Popular (30-59)  G#               1070
# Most Popular (90-100)       G#                 11
# Mid to High Popular (60-89) G#                711

# %%
key_group_3=key_group_2.loc['Low to Mid Popular (30-59)']
key_group_3= (key_group_3['count']) / (key_group_3['count'].sum()) * 100
key_group_3
# Out:
# Key Assignment
# A      9.313549
# A#     7.008572
# B      9.068645
# C     10.458835
# C#    12.216380
# D      8.521213
# D#     2.910034
# E      6.655622
# F      8.161060
# F#     8.016999
# G      9.961824
# G#     7.707268
# Name: count, dtype: float64

# %%
key_group_4=key_group_2.loc['Mid to High Popular (60-89)']
key_group_4= (key_group_4['count']) / (key_group_4['count'].sum()) * 100
key_group_4
# Out:
# Key Assignment
# A      9.332566
# A#     6.674338
# B      9.228999
# C     11.150748
# C#    12.508631
# D      8.181818
# D#     2.577675
# E      6.616801
# F      8.331415
# F#     8.101266
# G      9.113924
# G#     8.181818
# Name: count, dtype: float64

# %%
key_group_5=key_group_2.loc['Least Popular (<30)']
key_group_5= (key_group_5['count']) / (key_group_5['count'].sum()) * 100
key_group_5
# Out:
# Key Assignment
# A      8.487337
# A#     6.516085
# B      8.815880
# C     10.732375
# C#    12.128679
# D      9.075975
# D#     2.956879
# E      6.748802
# F      7.980835
# F#     8.336756
# G     11.745380
# G#     6.475017
# Name: count, dtype: float64

# %%
key_group_6=key_group_2.loc['Most Popular (90-100)']
key_group_6= (key_group_6['count']) / (key_group_6['count'].sum()) * 100
key_group_6
# Out:
# Key Assignment
# A      7.539683
# A#    15.079365
# B      8.730159
# C      3.968254
# C#    12.698413
# D     11.111111
# D#     0.000000
# E      2.777778
# F      3.174603
# F#    13.095238
# G     17.460317
# G#     4.365079
# Name: count, dtype: float64

# %%
key_popularity = pd.DataFrame({"Most Popular (90-100)": key_group_6,
                       "Mid to High Popular (60-89)": key_group_4,
                       "Low to Mid Popular ( 30-59)": key_group_3,
                       "Least Popular (<30)": key_group_5})   
pd.options.display.float_format = '{:.3f}%'.format

key_popularity.head()
# Out:
#                 Most Popular (90-100)  Mid to High Popular (60-89)  \
# Key Assignment
# A                              7.540%                       9.333%
# A#                            15.079%                       6.674%
# B                              8.730%                       9.229%
# C                              3.968%                      11.151%
# C#                            12.698%                      12.509%
#
#                 Low to Mid Popular ( 30-59)  Least Popular (<30)
# Key Assignment
# A                                    9.314%               8.487%
# A#                                   7.009%               6.516%
# B                                    9.069%               8.816%
# C                                   10.459%              10.732%
# C#                                  12.216%              12.129%

# %%
bar_5= key_group_2.loc['Least Popular (<30)']
bar_5.plot(kind='bar', figsize=(10,8), title= 'Least Popular (<30)',
           xlabel='Key Assignment', ylabel="Number of Songs", color='turquoise')
plt.show()

# %%
bar_4= key_group_2.loc['Low to Mid Popular (30-59)']
bar_4.plot(kind='bar', figsize=(10,8), title= 'Key Count of Low to Mid Popular (30-59)',
           xlabel='Key Assignment', ylabel="Number of Songs", color='darkorange')
plt.show()

# %%
bar_2= key_group_2.loc['Mid to High Popular (60-89)']
bar_2.plot(kind='bar', figsize=(10,8), title= 'Key Count of Mid to High Popular (60-89)',
           xlabel='Key Assignment', ylabel="Number of Songs", color='plum')
plt.show()

# %%
bar_1= key_group_2.loc['Most Popular (90-100)']
bar_1.plot(kind='bar', figsize=(10,8), title= 'Key Count of Most Popular (90-100)',
           xlabel='Key Assignment', ylabel="Number of Songs", color='lightblue')
plt.show()

# %%
# Shannon code from here down  

#  Keep either the copy or the reimport

# %%
spotify_data_genre = spotify_df.copy(deep=True)  # deep  changes made to original dont impact copy - true is default
spotify_data_genre.head()
# Out:
#                                                        Artist  Popularity  \
# Track Name
# At Last - Single Version                           Etta James          25
# (What A) Wonderful World - Remastered               Sam Cooke          13
# Jingle Bells                                  Ella Fitzgerald          11
# At Last - Single Version                           Etta James          15
# Green Onions                           Booker T. & the M.G.'s          64
#
#                                                 Popularity Sectors  \
# Track Name
# At Last - Single Version                       Least Popular (<30)
# (What A) Wonderful World - Remastered          Least Popular (<30)
# Jingle Bells                                   Least Popular (<30)
# At Last - Single Version                       Least Popular (<30)
# Green Onions                           Mid to High Popular (60-89)
#
#                                        Release Date  \
# Track Name
# At Last - Single Version                       1960
# (What A) Wonderful World - Remastered          1960
# Jingle Bells                                   1960
# At Last - Single Version                       1960
# Green Onions                                   1962
#
#                                                                            Playlist Name  \
# Track Name
# At Last - Single Version               The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...
# (What A) Wonderful World - Remastered  The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...
# Jingle Bells                                                              Christmas Soul
# At Last - Single Version                                                  Sexy Soul 2020
# Green Onions                                                   Supernatural Classic Rock
#
#                                       Genre            Subgenre  Key  \
# Track Name
# At Last - Single Version                r&b  urban contemporary    5
# (What A) Wonderful World - Remastered   r&b  urban contemporary   11
# Jingle Bells                            r&b            neo soul    7
# At Last - Single Version                r&b            neo soul    5
# Green Onions                           rock        classic rock   10
#
#                                       Key Assignment Loudness    Tempo  \
# Track Name
# At Last - Single Version                           F   -9.981  174.794
# (What A) Wonderful World - Remastered              B   -9.889  128.091
# Jingle Bells                                       G   -6.295  119.117
# At Last - Single Version                           F   -9.881  174.610
# Green Onions                                      A#   -8.741  136.837
#
#                                        Duration (ms)
# Track Name
# At Last - Single Version                      182400
# (What A) Wonderful World - Remastered         125507
# Jingle Bells                                  142547
# At Last - Single Version                      179893
# Green Onions                                  176333

# %%
#Pie chart playlist distro by Genre
custom_colors = ['grey', 'red', 'lightgreen', 'lightblue', 'purple','orange',]
paper = plt.figure(figsize=[10,6])
spotify_data_genre['Genre'].value_counts().plot.pie(autopct='%3.1f%%',colors=custom_colors)
plt.title('Genres')
plt.show()

# %%
#Categorize and Establish Bins for Eras
era_bins = (0, 1969, 1979, 1989, 1999, 2019, 2029)
labels = [1960, 1970, 1980, 1990, 2000, 2010] 

spotify_data_genre["Eras"] = pd.cut(spotify_data_genre["Release Date"],era_bins, labels=labels)


spotify_data_genre.head()
# Out:
#                                                        Artist  Popularity  \
# Track Name
# At Last - Single Version                           Etta James          25
# (What A) Wonderful World - Remastered               Sam Cooke          13
# Jingle Bells                                  Ella Fitzgerald          11
# At Last - Single Version                           Etta James          15
# Green Onions                           Booker T. & the M.G.'s          64
#
#                                                 Popularity Sectors  \
# Track Name
# At Last - Single Version                       Least Popular (<30)
# (What A) Wonderful World - Remastered          Least Popular (<30)
# Jingle Bells                                   Least Popular (<30)
# At Last - Single Version                       Least Popular (<30)
# Green Onions                           Mid to High Popular (60-89)
#
#                                        Release Date  \
# Track Name
# At Last - Single Version                       1960
# (What A) Wonderful World - Remastered          1960
# Jingle Bells                                   1960
# At Last - Single Version                       1960
# Green Onions                                   1962
#
#                                                                            Playlist Name  \
# Track Name
# At Last - Single Version               The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...
# (What A) Wonderful World - Remastered  The 1950s/1960s/1970s/1980s/1990s/2000s/2010s ...
# Jingle Bells                                                              Christmas Soul
# At Last - Single Version                                                  Sexy Soul 2020
# Green Onions                                                   Supernatural Classic Rock
#
#                                       Genre            Subgenre  Key  \
# Track Name
# At Last - Single Version                r&b  urban contemporary    5
# (What A) Wonderful World - Remastered   r&b  urban contemporary   11
# Jingle Bells                            r&b            neo soul    7
# At Last - Single Version                r&b            neo soul    5
# Green Onions                           rock        classic rock   10
#
#                                       Key Assignment Loudness    Tempo  \
# Track Name
# At Last - Single Version                           F   -9.981  174.794
# (What A) Wonderful World - Remastered              B   -9.889  128.091
# Jingle Bells                                       G   -6.295  119.117
# At Last - Single Version                           F   -9.881  174.610
# Green Onions                                      A#   -8.741  136.837
#
#                                        Duration (ms)  Eras
# Track Name
# At Last - Single Version                      182400  1960
# (What A) Wonderful World - Remastered         125507  1960
# Jingle Bells                                  142547  1960
# At Last - Single Version                      179893  1960
# Green Onions                                  176333  1960

# %%
spotify_data_genre.Genre.value_counts()
# Out:
# Genre
# edm      6043
# rap      5746
# pop      5507
# r&b      5431
# latin    5155
# rock     4951
# Name: count, dtype: int64

# %%
genrelist = spotify_data_genre['Genre'].unique().tolist()
genrelist
# Out:
# ['r&b', 'rock', 'rap', 'pop', 'latin', 'edm']

# %%
spotify_data_genre.Eras.value_counts()
# Out:
# Eras
# 2000    27291
# 1990     2310
# 1980     1306
# 1970      966
# 2010      785
# 1960      175
# Name: count, dtype: int64

# %%
genreYear_avg_popularity = pd.DataFrame(spotify_data_genre.groupby(["Genre", "Release Date"])["Popularity"].mean()).reset_index()
#genre_avg_popularity.info()


genreYear_avg_popularity = genreYear_avg_popularity[genreYear_avg_popularity["Release Date"]>2010]
genreYear_avg_popularity.head()
# Out:
#    Genre  Release Date  Popularity
# 26   edm          2011     32.797%
# 27   edm          2012     35.324%
# 28   edm          2013     19.783%
# 29   edm          2014     20.805%
# 30   edm          2015     26.433%

# %%
#Prep Average Popularity by Genre by Time

edm_avg_popularity = genreYear_avg_popularity[genreYear_avg_popularity["Genre"]=="edm"]
latin_avg_popularity = genreYear_avg_popularity[genreYear_avg_popularity["Genre"]=="latin"]
pop_avg_popularity = genreYear_avg_popularity[genreYear_avg_popularity["Genre"]=="pop"]
rb_avg_popularity = genreYear_avg_popularity[genreYear_avg_popularity["Genre"]=="r&b"]
rap_avg_popularity = genreYear_avg_popularity[genreYear_avg_popularity["Genre"]=="rap"]
rock_avg_popularity = genreYear_avg_popularity[genreYear_avg_popularity["Genre"]=="rock"]

rap_avg_popularity
# Out:
#     Genre  Release Date  Popularity
# 231   rap          2011     31.538%
# 232   rap          2012     31.248%
# 233   rap          2013     24.688%
# 234   rap          2014     30.874%
# 235   rap          2015     40.098%
# 236   rap          2016     40.458%
# 237   rap          2017     37.749%
# 238   rap          2018     43.475%
# 239   rap          2019     53.818%
# 240   rap          2020     50.635%

# %%
#Plot line chart of Genres by Popularity for 2011 to 2020
x_axis = rock_avg_popularity["Release Date"]

edm, = plt.plot(x_axis, edm_avg_popularity["Popularity"], marker="o", color="Black", linewidth=1, label="EDM")
latin, = plt.plot(x_axis, latin_avg_popularity["Popularity"], marker="o", color="Purple", linewidth=1, label="Latin")
pop, = plt.plot(x_axis, pop_avg_popularity["Popularity"], marker="o", color="Green", linewidth=1, label="Pop")
rb, = plt.plot(x_axis, rb_avg_popularity["Popularity"], marker="o", color="Blue", linewidth=1, label="R&B")
rap, = plt.plot(x_axis, rap_avg_popularity["Popularity"], marker="o", color="Red", linewidth=1, label="Rap")
rock, = plt.plot(x_axis, rock_avg_popularity["Popularity"], marker="o", color="Orange", linewidth=1, label="Rock")

plt.legend(handles=[edm, latin, rock, pop, rb, rap], loc="best")
#plt.figure(figsize=(8,6))
plt.title("Genres by Average Popularity 2011 to 2020")
plt.xlabel("Year")
plt.ylabel("Genre")
#plt.figure().set_figwidth(20)
#plt.rcParams['figure.figsize'] = [8,5]
plt.savefig("New Genres by Average Popularity 2011 to 2020")
plt.show()

# %%
genre_avg_popularity = pd.DataFrame(spotify_data_genre.groupby(["Genre"])["Popularity"].mean()).reset_index()
genre_avg_popularity
# Out:
#    Genre  Popularity
# 0    edm     34.834%
# 1  latin     47.027%
# 2    pop     47.745%
# 3    r&b     41.224%
# 4    rap     43.215%
# 5   rock     41.728%

# %%
#Plot Average Popularity by Genres


x_axis = np.arange(len(genre_avg_popularity["Genre"]))

plt.bar(x_axis, genre_avg_popularity["Popularity"], color="b", alpha=0.5, align="center")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations,genre_avg_popularity["Genre"], rotation="vertical")
plt.show()

# %%
genreEra_avg_popularity = pd.DataFrame(spotify_data_genre.groupby(["Genre","Eras"])["Popularity"].mean()).reset_index()
genreEra_avg_popularity= genreEra_avg_popularity.dropna()
genreEra_avg_popularity.head()
# Out:
#   Genre  Eras  Popularity
# 1   edm  1970     24.000%
# 2   edm  1980     37.400%
# 3   edm  1990     39.300%
# 4   edm  2000     34.658%
# 5   edm  2010     40.315%

# %%
era_list = genreEra_avg_popularity['Eras'].unique().tolist()
era_list
# Out:
# [1970, 1980, 1990, 2000, 2010, 1960]

# %%
era = 1970
era_df = genreEra_avg_popularity[genreEra_avg_popularity["Eras"]==era].sort_values(["Eras"])
era_df

#sort_values(['Popularity'], ascending=False)
# Out:
#     Genre  Eras  Popularity
# 1     edm  1970     24.000%
# 7   latin  1970     63.250%
# 13    pop  1970     60.278%
# 19    r&b  1970     47.033%
# 25    rap  1970     39.333%
# 31   rock  1970     46.462%

# %%
#Plot Average Popularity by Genres
for era in era_list:
    era_df = genreEra_avg_popularity[genreEra_avg_popularity["Eras"]==era]


    x_axis = np.arange(len(era_df["Genre"]))

    plt.bar(x_axis, era_df["Popularity"], color="b", alpha=0.5, align="center")
    tick_locations = [value for value in x_axis]
    plt.xticks(tick_locations,era_df["Genre"], rotation="vertical")
    plt.title("Popularity by Genre " + str(era))
    plt.savefig("Popularity by Genre "+ str(era))
    plt.show()

# %%
artist_df = pd.DataFrame(spotify_df.groupby(['Artist'])['Popularity'].mean()).sort_values(['Popularity'], ascending=False).reset_index()

artist_df.head()
# Out:
#           Artist  Popularity
# 0  Trevor Daniel     97.000%
# 1            Y2K     91.000%
# 2    Don Toliver     90.714%
# 3    Roddy Ricch     88.211%
# 4         DaBaby     87.857%

# %%
spotify_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32833 entries, At Last - Single Version to Tainted Love
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Artist              32828 non-null  object
#  1   Popularity          32833 non-null  int64
#  2   Popularity Sectors  30130 non-null  category
#  3   Release Date        32833 non-null  int64
#  4   Playlist Name       32833 non-null  object
#  5   Genre               32833 non-null  object
#  6   Subgenre            32833 non-null  object
#  7   Key                 32833 non-null  int64
#  8   Key Assignment      32833 non-null  object
#  9   Loudness            32833 non-null  object
#  10  Tempo               32833 non-null  object
#  11  Duration (ms)       32833 non-null  int64
# dtypes: category(1), int64(4), object(7)
# memory usage: 4.0+ MB

# %%
#song_df = pd.DataFrame(spotify_df.groupby(['Track Name'])['Popularity'].mean()).sort_values(['Popularity'], ascending=False).reset_index()

#song_df.head()
# Out:
#                   Track Name  Popularity
# 0                       Tusa     98.000%
# 1                    The Box     98.000%
# 2        everything i wanted     97.000%
# 3            Don't Start Now     97.000%
# 4  RITMO (Bad Boys For Life)     96.000%

# %%
song_df = pd.DataFrame(spotify_df.groupby(['Playlist Name'])['Popularity'].mean()).sort_values(['Popularity'], ascending=False).reset_index()

song_df.head()
# Out:
#                                      Playlist Name  Popularity
# 0   2020 Hits & 2019  Hits – Top Global Tracks 🔥🔥🔥     83.186%
# 1                                        RapCaviar     79.700%
# 2                         Most Popular 2020 TOP 50     79.333%
# 3  Pop - Pop UK - 2019 - Canadian Pop - 2019 - Pop     79.130%
# 4                                  Baila Reggaeton     77.700%

# %%
#songArtist_df = pd.DataFrame(spotify_df.groupby(['Track Name', 'Artist'])['Popularity'].mean()).sort_values(['Popularity'], ascending=False).reset_index()

#songArtist_df.head(10)

# %%
import scipy.stats as st
popularity = song_df['Popularity']
plt.hist(popularity)
plt.xlabel('Popularity Score')
plt.ylabel('Count of Playlists')
plt.show()
print(st.normaltest(popularity.sample(50)))


mean_numpy = np.mean(popularity)
print(f"The mean popularity of playlists is {mean_numpy}")

median_numpy = np.median(popularity)
print(f"The median popularity of playlists is {median_numpy}")

mode_scipy = st.mode(popularity)
print(f"The popularity of playlists is {mode_scipy}")
print(' ')

var_numpy = np.var(popularity,ddof = 0)
print(f"The population variance using the NumPy module is {var_numpy}")

sd_numpy = np.std(popularity,ddof = 0)
print(f"The population standard deviation using the NumPy module is {sd_numpy}")
print(' ')
print(f"Roughly 68% of the data is between {round(mean_numpy-sd_numpy,3)} and {round(mean_numpy+sd_numpy,3)}")
print(f"Roughly 95% of the data is between {round(mean_numpy-2*sd_numpy,3)} and {round(mean_numpy+2*sd_numpy,3)}")
print(f"Roughly 99.7% of the data is between {round(mean_numpy-3*sd_numpy,3)} and {round(mean_numpy+3*sd_numpy,3)}")
print(' ')
# Out:
# NormaltestResult(statistic=1.2675660465547283, pvalue=0.5305808000563881)
# The mean popularity of playlists is 39.43265758826692
# The median popularity of playlists is 42.0
# The popularity of playlists is ModeResult(mode=0.0, count=1943)
#
# The population variance using the NumPy module is 501.7368063387134
# The population standard deviation using the NumPy module is 22.39948227836334
#
# Roughly 68% of the data is between 17.033 and 61.832
# Roughly 95% of the data is between -5.366 and 84.232
# Roughly 99.7% of the data is between -27.766 and 106.631

# %%
z_scipy = st.zscore(popularity)
print(f"The z-scores using the SciPy module are {z_scipy}")
# Out:
# The z-scores using the SciPy module are 0        2.615%
# 1        2.615%
# 2        2.570%
# 3        2.570%
# 4        2.525%
#           ...
# 23443   -1.760%
# 23444   -1.760%
# 23445   -1.760%
# 23446   -1.760%
# 23447   -1.760%
# Name: Popularity, Length: 23448, dtype: float64

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Popularity score of Spotify Playlists')
ax1.set_ylabel('Popularity')
ax1.boxplot(popularity)
plt.show()

# %%
quartiles = popularity.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of popularity is: {lowerq}")
print(f"The upper quartile of popularity is: {upperq}")
print(f"The interquartile range of popularity is: {iqr}")
print(f"The the median of popularity is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of popularity is: 24.0
# The upper quartile of popularity is: 57.0
# The interquartile range of popularity is: 33.0
# The the median of popularity is: 42.0
# Values below -25.5 could be outliers.
# Values above 106.5 could be outliers.
